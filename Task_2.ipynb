# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
csvFile = 'Datasets/data/task2/imu_calibration_task2.csv'
calib_data = np.loadtxt(csvFile, delimiter=',', skiprows=0)
calib_data.shape
time_stamp = calib_data[:, 0]
acc_x, acc_y, acc_z = calib_data[:, 1], calib_data[:, 2], calib_data[:, 3]
roll, pitch = calib_data[:, 4], calib_data[:, 5]
gyro_x, gyro_y, gyro_z = , calib_data[:, 6]
mag_x, mag_y, mag_z = 

for i in range(12):
    plt.figure()
    plt.plot(calib_data[:, i])
# Out:
# (3700, 12)

# %%
variable_names = ['time_stamp', 'acc_x', 'acc_y', 'acc_z', 'roll', 'pitch', 
                    'gyro_x', 'gyro_y', 'gyro_z', 'mag_x', 'mag_y', 'mag_z']
plt.figure(figsize=(18, 15))
for idx, name in enumerate(variable_names):
    exec(name + '=calib_data[:,'+str(idx)+']')
    plt.subplot(4, 3, idx+1)
    plt.plot(locals().get(name))
    plt.grid()
    plt.title(name, fontsize=14)
